# %% [markdown]
# # This is Code Generated from Sample.md

# %%
import sys
print(sys.version)
# Out:
# 3.12.4 (tags/v3.12.4:8e8a4ba, Jun  6 2024, 19:30:16) [MSC v.1940 64 bit (AMD64)]

# %%
def sort_and_find_max(arr):
    sorted_arr = sorted(arr)
    largest = sorted_arr[-1]
    print("The sorted array is:", sorted_arr)
    print("The largest number is:", largest)
    return sorted_arr, largest

# %%
numbers = [1009, 2322, 900, 43, 116000, 78, 2000000, 65444, 45999, 7654, 85000, 435, 567, 9876]
sort_and_find_max(numbers)
# Out:
# The sorted array is: [43, 78, 435, 567, 900, 1009, 2322, 7654, 9876, 45999, 65444, 85000, 116000, 2000000]
# The largest number is: 2000000
# ([43,
#   78,
#   435,
#   567,
#   900,
#   1009,
#   2322,
#   7654,
#   9876,
#   45999,
#   65444,
#   85000,
#   116000,
#   2000000],
#  2000000)
